# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib
# %matplotlib inline

# %%
df =  pd.read_csv(r'C:\Users\shubh\Jupyter Notebook\Datasets\Zomatodataset\zomato.csv',encoding='latin-1')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ## In Data Analysis What All Things We Do
#
# 1. Missing Values
# 2. Explore About the Numerical Variables
# 3. Explore About Categorical Variables
# 4. Finding Relationship between Features

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>1]
# Out:
# ['Cuisines']

# %%
matplotlib.rcParams['figure.figsize'] = (12,6)
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df_country = pd.read_excel('C:\\Users\shubh\Jupyter Notebook\Datasets\Zomatodataset\Country-Code.xlsx')

# %%
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
final_df = pd.merge(df,df_country,on='Country Code',how= 'left')

# %%
final_df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
country_names = final_df.Country.value_counts().index

# %%
country_names
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object')

# %%
country_val = final_df.Country.value_counts().values

# %%
## Pie Chart - Top 3 Countries that uses zomato
plt.pie(country_val[:3] , labels= country_names[:3], autopct="%1.2f%%" )
# Out:
# ([<matplotlib.patches.Wedge at 0x26a42714280>,
# ...
#  [Text(-1.0829742700952103, 0.19278674827836725, 'India'),
#   Text(1.077281715838356, -0.22240527134123297, 'United States'),
#   Text(1.0995865153823035, -0.03015783794312073, 'United Kingdom')],
#  [Text(-0.590713238233751, 0.10515640815183668, '94.39%'),
#   Text(0.5876082086391032, -0.12131196618612707, '4.73%'),
#   Text(0.5997744629358018, -0.01644972978715676, '0.87%')])

# %% [markdown]
# Observation 1: Zomato is majorly operating in 1 country that is India.
# <br> Observation 2: Zomato maximum records or transactions are from India followed by United States and United Kingdom

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
#for Observation No: 3
ratings= final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text' ]).size().reset_index().rename(columns={0:'Rating Count'})

# %%
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %%
#for Observation No: 4
final_df['Rating text'].size
# Out:
# 9551

# %%
final_df['Rating text'].value_counts()
# Out:
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: Rating text, dtype: int64

# %%
# for Pie Chart of Ratings
rating_values = final_df['Rating text'].value_counts().values

# %%
rating_values
# Out:
# array([3737, 2148, 2100, 1079,  301,  186], dtype=int64)

# %%
rating_comment = final_df['Rating text'].value_counts().index

# %%
rating_comment
# Out:
# Index(['Average', 'Not rated', 'Good', 'Very Good', 'Excellent', 'Poor'], dtype='object')

# %% [markdown]
# #### Observation No: 3
# Ratings Chart shows that <br>
# Ratings between 1.8 and 2.4 are Rated 'POOR' & 'RED' in Color <br>
# Ratings between 2.5 and 3.4 are Rated 'AVERAGE' & 'ORANGE' in Color <br>
# Ratings between 3.5 and 3.9 are Rated 'GOOD' & 'YELLOW' in Color <br>
# Ratings between 4.0 and 4.4 are Rated 'VERY GOOD' & 'GREEN' in Color <br>
# Ratings between 4.5 and 4.9 are Rated 'EXCELLENT' & 'DARK GREEN' in Color <br>

# %% [markdown]
# #### Observation No: 4 <br>
# Out of Total 9551 (100%) Restaurants <br>
# Only 7403 (77.51%) Restaurants are Rated and <br>
# Rest 2148 (22.49%) are NOT Rated.

# %%
# Pie Chart of Ratings
plt.pie(rating_values , labels= rating_comment, autopct="%1.2f%%",)
# Out:
# ([<matplotlib.patches.Wedge at 0x26a427e5130>,
# ...
#  [Text(0.3684861700797763, 1.0364448574140055, 'Average'),
#   Text(-1.0997000414954674, -0.02568693704721014, 'Not rated'),
#   Text(-0.16455128028787028, -1.087622579829797, 'Good'),
#   Text(0.8585786329981524, -0.6876356091412253, 'Very Good'),
#   Text(1.0731576417576685, -0.24152158482653235, 'Excellent'),
#   Text(1.0979419528893613, -0.06725673264065082, 'Poor')],
#  [Text(0.2009924564071507, 0.5653335585894576, '39.13%'),
#   Text(-0.5998363862702549, -0.014011056571205528, '22.49%'),
#   Text(-0.08975524379338379, -0.5932486799071619, '21.99%'),
#   Text(0.4683156179989922, -0.3750739686224865, '11.30%'),
#   Text(0.5853587136860009, -0.13173904626901764, '3.15%'),
#   Text(0.5988774288487424, -0.03668549053126408, '1.95%')])

# %%
ratings.head()
# Out:
#    Aggregate rating Rating color Rating text  Rating Count
# 0               0.0        White   Not rated          2148
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15

# %%
new_ratings = ratings.drop(0) #removing the non rated restaurants from dataset
new_ratings.head()
# Out:
#    Aggregate rating Rating color Rating text  Rating Count
# 1               1.8          Red        Poor             1
# 2               1.9          Red        Poor             2
# 3               2.0          Red        Poor             7
# 4               2.1          Red        Poor            15
# 5               2.2          Red        Poor            27

# %%
new_ratings.describe()
# Out:
#        Aggregate rating  Rating Count
# count         32.000000     32.000000
# mean           3.350000    231.343750
# std            0.938083    184.687986
# min            1.800000      1.000000
# 25%            2.575000     57.500000
# 50%            3.350000    206.000000
# 75%            4.125000    406.750000
# max            4.900000    522.000000

# %%
# barplot of Different Ratings
sns.barplot(x='Aggregate rating', y='Rating Count', data=new_ratings, hue = 'Rating color' ,  palette=['red', 'orange', 'yellow', 'green', 'green'] )
# Out:
# <AxesSubplot:xlabel='Aggregate rating', ylabel='Rating Count'>

# %% [markdown]
# #### Observations
# 1. Most of the Restaurants are Rated between 2.7 and 4.2 (More than Avg of Total Ratings)

# %%
# for Observation No: 5
price_ratings = final_df[['Price range', 'Aggregate rating']]
price_ratings.head()
# Out:
#    Price range  Aggregate rating
# 0            3               4.8
# 1            3               4.5
# 2            4               4.4
# 3            4               4.9
# 4            4               4.8

# %%
price_ratings.groupby(['Price range']).mean().round(1)
# Out:
#              Aggregate rating
# Price range
# 1                         2.0
# 2                         2.9
# 3                         3.7
# 4                         3.8

# %% [markdown]
# #### Observation No: 5
#
# High Price Range is not ensureing the High ratings.

# %%
# Countries that has not given any rating to Restaurants Count
final_df[final_df['Rating text']=='Not rated'].groupby('Country').size().reset_index().rename(columns={0:'Non Rated Restaurants'})
# Out:
#           Country  Non Rated Restaurants
# 0          Brazil                      5
# 1           India                   2139
# 2  United Kingdom                      1
# 3   United States                      3

# %% [markdown]
# Observation: <br>
# India has the Highest No of Non Rated Restaurants

# %%
# Currencies used by different Countries.
# Arranged in Descending Order
final_df.groupby(['Country','Currency']).size().reset_index().rename(columns={0:'Use Occurances'}).sort_values(by=['Use Occurances'], ascending=False).reset_index().drop('index',axis=1)
# Out:
#            Country                Currency  Use Occurances
# 0            India      Indian Rupees(Rs.)            8652
# 1    United States               Dollar($)             434
# 2   United Kingdom              Pounds(£)              80
# 3           Brazil      Brazilian Real(R$)              60
# 4     South Africa                 Rand(R)              60
# 5              UAE      Emirati Diram(AED)              60
# 6      New Zealand           NewZealand($)              40
# 7           Turkey        Turkish Lira(TL)              34
# 8        Australia               Dollar($)              24
# 9      Phillipines        Botswana Pula(P)              22
# 10       Indonesia  Indonesian Rupiah(IDR)              21
# 11           Qatar         Qatari Rial(QR)              20
# 12       Singapore               Dollar($)              20
# 13       Sri Lanka   Sri Lankan Rupee(LKR)              20
# 14          Canada               Dollar($)               4

# %%
# Countries categoried by Online Delivery
final_df.groupby(['Country','Has Online delivery']).size().reset_index().rename(columns={0: 'No of Restaurants'})
# Out:
#            Country Has Online delivery  No of Restaurants
# 0        Australia                  No                 24
# 1           Brazil                  No                 60
# 2           Canada                  No                  4
# 3            India                  No               6229
# 4            India                 Yes               2423
# 5        Indonesia                  No                 21
# 6      New Zealand                  No                 40
# 7      Phillipines                  No                 22
# 8            Qatar                  No                 20
# 9        Singapore                  No                 20
# 10    South Africa                  No                 60
# 11       Sri Lanka                  No                 20
# 12          Turkey                  No                 34
# 13             UAE                  No                 32
# 14             UAE                 Yes                 28
# ...

# %% [markdown]
# Observations: <br>
# 1. India and UAE has both No Delivery and Delivery Restaurants.
# 2. India has Most No of Delivery Restaurants and Non Delivery Restaurants.
# 3. India and UAE are the only Countries where Online Delivery is Available.

# %%
city_values = final_df.City.value_counts().values
city_labels = final_df.City.value_counts().index

# %%
plt.pie(city_values[:5], labels= city_labels[:5], autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x26a49ffd820>,
# ...
#  [Text(-0.6145352824185932, 0.9123301960708633, 'New Delhi'),
#   Text(0.0623675251198054, -1.0982305276263407, 'Gurgaon'),
#   Text(0.8789045225625368, -0.6614581167535246, 'Noida'),
#   Text(1.0922218418223437, -0.13058119407559224, 'Faridabad'),
#   Text(1.099946280005612, -0.010871113182029924, 'Ghaziabad')],
#  [Text(-0.3352010631374145, 0.497634652402289, '68.87%'),
#   Text(0.0340186500653484, -0.5990348332507311, '14.07%'),
#   Text(0.47940246685229276, -0.36079533641101336, '13.59%'),
#   Text(0.5957573682667329, -0.07122610585941394, '3.16%'),
#   Text(0.5999706981848791, -0.005929698099289049, '0.31%')])

# %% [markdown]
# Observations <br>
# Maximum Number of Restaurants are located in Delhi-NCR Region.

# %%
# top 10 cuisines which are served at Restaurants
final_df[['Cuisines']].value_counts().reset_index().head(10).rename(columns={0:'No. of Restaurants'})
# Out:
#                          Cuisines  No. of Restaurants
# 0                    North Indian                 936
# 1           North Indian, Chinese                 511
# 2                         Chinese                 354
# 3                       Fast Food                 354
# 4           North Indian, Mughlai                 334
# 5                            Cafe                 299
# 6                          Bakery                 218
# 7  North Indian, Mughlai, Chinese                 197
# 8                Bakery, Desserts                 170
# 9                     Street Food                 149

# %%
cuisines_index= final_df[['Cuisines']].value_counts().index
cuisines_value= final_df[['Cuisines']].value_counts().values

# %%
plt.pie(cuisines_value[:10], labels= cuisines_index[:10], autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x26a48aa0e50>,
# ...
#  [Text(0.7383739846958008, 0.8153550507137645, "('North Indian',)"),
#   Text(-0.5794679314239953, 0.9349956772366362, "('North Indian, Chinese',)"),
#   Text(-1.067309479615702, 0.26617752482593154, "('Chinese',)"),
#   Text(-1.0185984499802057, -0.4152796620326146, "('Fast Food',)"),
#   Text(-0.5935788454809928, -0.9261015895664211, "('North Indian, Mughlai',)"),
#   Text(-0.005887079599915552, -1.0999842463843672, "('Cafe',)"),
#   Text(0.4842062514572988, -0.9876964645323336, "('Bakery',)"),
#   Text(0.808736477166136, -0.7456174022251013, "('North Indian, Mughlai, Chinese',)"),
#   Text(1.0055375294202338, -0.44597564611473206, "('Bakery, Desserts',)"),
#   Text(1.090298995560443, -0.14576728123927227, "('Street Food',)")],
#  [Text(0.4027494461977095, 0.4447391185711442, '26.58%'),
#   Text(-0.316073417140361, 0.5099976421290743, '14.51%'),
#   Text(-0.5821688070631101, 0.14518774081414446, '10.05%'),
# ...

# %% [markdown]
# Observations <br>
# 1. North Indian Food is Mostly Served by Restaurants
# 2. Chinese Food is Served after North Indian followed by Fast Food, Cafe and Bakery.

# %%
final_df.groupby(['Price range','Has Table booking']).size().reset_index(name='No. of Restaurants')
# Out:
#    Price range Has Table booking  No. of Restaurants
# 0            1                No                4443
# 1            1               Yes                   1
# 2            2                No                2874
# 3            2               Yes                 239
# 4            3                No                 764
# 5            3               Yes                 644
# 6            4                No                 312
# 7            4               Yes                 274

# %% [markdown]
# Observation: <br>
# 1. Restaurants with Price Range 1 has NO Table Booking
# 2. Only 7.7% Restaurants in Price Range 2 offer Table Booking
# 3. Almost Half of the Restaurants in Price Range 3 and 4 offer Table Booking.
